# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import concat_ws, col,regexp_replace
import pyspark.sql.functions as F
from pyspark.ml.feature import Imputer
from pyspark.ml.feature import VectorAssembler , StringIndexer
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline

# %%
# Set JAVA_HOME to the path of Java 17
# (This command finds the path dynamically using the mac system tool)
java17_path = os.popen("/usr/libexec/java_home -v 17").read().strip()

if java17_path:
    os.environ["JAVA_HOME"] = java17_path
    print(f"Successfully set JAVA_HOME to: {java17_path}")
else:
    print("Error: Java 17 not found! Please verify installation.")
# Out:
# Successfully set JAVA_HOME to: /Library/Java/JavaVirtualMachines/jdk-17.jdk/Contents/Home

# %%
spark=SparkSession.builder.appName("Streaming Data").getOrCreate()
spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/01 12:39:05 WARN Utils: Your hostname, Mushtaq.local, resolves to a loopback address: 127.0.0.1; using 192.168.68.66 instead (on interface en0)
# 26/01/01 12:39:05 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/01 12:39:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/01 12:39:06 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.68.66:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Streaming Data</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
retail=spark.read.csv('../data/raw/2010-12-01.csv',
header=True,
inferSchema=True,
sep=",",
quote='"',
escape='"',
multiLine=True,
mode="PERMISSIVE")
